# %%
import pandas as pd
import numpy as np

# %%
mysub = pd.read_csv('../submission_files/leak/not_submitted/08. stackcb_unionf.csv')
leak1 = pd.read_csv('../submission_files/leak/public/01. test_leak.csv', usecols=['compiled_leak']).replace(np.nan, 0.)
leak2 = pd.read_csv('../submission_files/leak/not_submitted/new_submission.csv')

# %%
leak2_idx = leak2[leak2.target != leak2.target[0]].index.values
leak2_vals = leak2[leak2.target != leak2.target[0]].target.values

leak2_idx = leak2[leak2.target != leak2.target[0]].index.values
leak2_vals = leak2[leak2.target != leak2.target[0]].target.values

leak1_idx = leak1[leak1.compiled_leak != 0.].index.values
leak1_vals = leak1.compiled_leak[leak1_idx].values

# %%
leak2_vals = np.round(np.expm1(leak2_vals))

# %%
leak1.iloc[10]
# Out:
# compiled_leak    20000000.0
# Name: 10, dtype: float64

# %%
leak2_idx
# Out:
# array([    2,    10,    43, ..., 49314, 49325, 49326], dtype=int64)

# %%
leak1_idx
# Out:
# array([   10,    43,    48, ..., 49325, 49326, 49332], dtype=int64)

# %%
sub3.target[leak2_idx] = leak2_vals
# Out:
# c:\users\cesar\anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sub3.target[leak1_idx] = leak1_vals
# Out:
# c:\users\cesar\anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
mysub
# Out:
#               ID      target
# 0      000137c73   2159000.0
# 1      00021489f   1449000.0
# 2      0004d7953   5002000.0
# 3      00056a333   4124000.0
# 4      00056d8eb   2092000.0
# 5      0005fc190   2597000.0
# 6      000787e86   2126000.0
# 7      0008510a0   3024000.0
# 8      000895faf   3312000.0
# 9      000986fba   3338000.0
# 10     0009efcc5  20000000.0
# 11     000dd8f00  12261000.0
# 12     000e1cdc2   1823000.0
# 13     00103739c   2086000.0
# 14     00134b367   2121000.0
# 15     001788d0d    788000.0
# 16     0019c8ad7   2340000.0
# 17     001a267b9    628000.0
# 18     001a85486   2081000.0
# 19     001c4de06   2200000.0
# 20     001f9014b   3815000.0
# 21     00216fb94   4227000.0
# 22     00235690e   3009000.0
# 23     00240739d   6945000.0
# 24     0024c3747   1653000.0
# 25     00297052d   2418000.0
# 26     002ab8f85   2327000.0
# 27     002bed5c0   1902000.0
# 28     002bf3974   4656000.0
# 29     002d23a26   2830000.0
# ...          ...         ...
# ...

# %%
mysub.to_csv('../submission_files/leak/not_submitted/newnew.csv', index=False)

# %%
sub2 = pd.read_csv('../submission_files/leak/public/02. loveanswer_v11_maybe_063.csv')

# %%
sub3 = mysub.copy()

# %%
sub3.target = 0.5*mysub.target + 0.5*sub2.target

# %%
sub3.to_csv("../submission_files/leak/blaaaaa2.csv", index=False)

# %%
sub3
# Out:
#               ID        target
# 0      000137c73  2.026232e+06
# 1      00021489f  1.321269e+06
# 2      0004d7953  5.002000e+06
# 3      00056a333  4.922257e+06
# 4      00056d8eb  1.818791e+06
# 5      0005fc190  2.869846e+06
# 6      000787e86  1.704387e+06
# 7      0008510a0  2.579110e+06
# 8      000895faf  3.151602e+06
# 9      000986fba  2.658321e+06
# 10     0009efcc5  2.000000e+07
# 11     000dd8f00  1.321911e+07
# 12     000e1cdc2  1.636985e+06
# 13     00103739c  2.256339e+06
# 14     00134b367  1.698697e+06
# 15     001788d0d  1.326683e+06
# 16     0019c8ad7  2.193771e+06
# 17     001a267b9  7.304085e+05
# 18     001a85486  1.824449e+06
# 19     001c4de06  2.311895e+06
# 20     001f9014b  3.624805e+06
# 21     00216fb94  4.521004e+06
# 22     00235690e  3.288702e+06
# 23     00240739d  8.026884e+06
# 24     0024c3747  1.596673e+06
# 25     00297052d  2.038187e+06
# 26     002ab8f85  1.740856e+06
# 27     002bed5c0  1.874020e+06
# 28     002bf3974  4.071762e+06
# ...
